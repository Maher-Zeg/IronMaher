# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
iris = pd.read_csv(r'C:\Users\Utilisateur\Desktop\DAFT_NOV_21_01-main\module_3\3. Data-Cleaning-Challenge\iris-data.csv')

# %%
iris.head()
# Out:
#    sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm  \
# 0              5.1             3.5              1.4             0.2
# 1              4.9             3.0              1.4             0.2
# 2              4.7             3.2              1.3             0.2
# 3              4.6             3.1              1.5             0.2
# 4              5.0             3.6              1.4             0.2
#
#          class
# 0  Iris-setosa
# 1  Iris-setosa
# 2  Iris-setosa
# 3  Iris-setosa
# 4  Iris-setosa

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   sepal_length_cm  150 non-null    float64
#  1   sepal_width_cm   150 non-null    float64
#  2   petal_length_cm  150 non-null    float64
#  3   petal_width_cm   145 non-null    float64
#  4   class            150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
iris.describe()
# Out:
#        sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm
# count       150.000000      150.000000       150.000000      145.000000
# mean          5.644627        3.054667         3.758667        1.236552
# std           1.312781        0.433123         1.764420        0.755058
# min           0.055000        2.000000         1.000000        0.100000
# 25%           5.100000        2.800000         1.600000        0.400000
# 50%           5.700000        3.000000         4.350000        1.300000
# 75%           6.400000        3.300000         5.100000        1.800000
# max           7.900000        4.400000         6.900000        2.500000

# %%
iris['petal_width_cm'].describe()
# Out:
# count    145.000000
# mean       1.236552
# std        0.755058
# min        0.100000
# 25%        0.400000
# 50%        1.300000
# 75%        1.800000
# max        2.500000
# Name: petal_width_cm, dtype: float64

# %%
iris['class'].value_counts()
# Out:
# Iris-virginica     50
# Iris-setosa        49
# Iris-versicolor    45
# versicolor          5
# Iris-setossa        1
# Name: class, dtype: int64

# %%
average_petal_width = iris.loc[iris['class'] == 'Iris-setosa', 'petal_width_cm'].mean()
iris.loc[(iris['class'] == 'Iris-setosa') &
              (iris['petal_width_cm'].isnull()),
              'petal_width_cm'] = average_petal_width

# %%
iris
# Out:
#      sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm  \
# 0                5.1             3.5              1.4             0.2
# 1                4.9             3.0              1.4             0.2
# 2                4.7             3.2              1.3             0.2
# 3                4.6             3.1              1.5             0.2
# 4                5.0             3.6              1.4             0.2
# ..               ...             ...              ...             ...
# 145              6.7             3.0              5.2             2.3
# 146              6.3             2.5              5.0             2.3
# 147              6.5             3.0              5.2             2.0
# 148              6.2             3.4              5.4             2.3
# 149              5.9             3.0              5.1             1.8
#
#               class
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# ...

# %%
# %matplotlib inline
sns.pairplot(iris.dropna(), hue = 'class')

# %%
plt.figure(figsize=(10, 6))
plt.subplot(1,4,1)
iris.boxplot(column=['sepal_length_cm']) 
plt.subplot(1,4,2)
iris.boxplot(column=['sepal_width_cm'])
plt.subplot(1,4,3)
iris.boxplot(column=['petal_length_cm'])
plt.subplot(1,4,4)
iris.boxplot(column=['petal_width_cm'])
# Out:
# <AxesSubplot:>

# %%
iris.to_excel(r'C:\Users\Utilisateur\Desktop\IronHack\IronMaher\MODULE 3\LAB 3\iris.xlsx', index = False)
